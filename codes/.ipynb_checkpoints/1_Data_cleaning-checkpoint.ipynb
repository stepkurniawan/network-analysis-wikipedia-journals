# %%
#!pip install -r Requirements.txt

# %%
#!pip install pyarrow

# %%
## All imports
import nltk
import numpy as np
import pandas as pd
import networkx as nx
import seaborn as sns
from tqdm import tqdm
from collections import Counter
import matplotlib.pyplot as plt

# %%
INPUT_DATA = 'C:\\Users\\Beka\\Downloads\\citations_from_wikipedia\\dataset.parquet'

# %%
## Reading the dataset
citations = pd.read_parquet(INPUT_DATA)
print('Total number of rows in the whole dataset: {}'.format(citations.count()))
# Out:
# Total number of rows in the whole dataset: AccessDate              134324
# Authors               11854817
# Chapter                 350551
# Chron                   135156
# City                         7
# Date                  17152154
# Degree                    4953
# Edition                 292512
# Encyclopedia             55592
# Format                  264685
# ID_list                3928392
# Issue                  1692004
# Pages                  4639675
# Periodical            14491903
# PublicationPlace       2127304
# PublisherName         12900448
# Series                  249148
# SeriesNumber          16053666
# Title                 28753918
# TitleType               175416
# URL                   24956769
# Volume                 1990887
# citations             29276667
# id                    29276667
# page_title            29276667
# r_id                  29276667
# r_parentid            29237202
# sections              29276667
# type_of_citation      29276667
# metadata_file           262909
# updated_identifier      262909
# conf_score              262909
# dtype: int64

# %%
print(citations["type_of_citation"].unique())
# Out:
# ['citation' 'cite av media notes' 'cite av media' 'cite book'
#  'cite episode' 'cite gnis' 'cite news' 'cite sports-reference' 'cite web'
#  'cite arxiv' 'cite conference' 'cite encyclopedia' 'cite journal'
#  'cite map' 'cite podcast' 'cite press release' 'cite report' 'cite sign'
#  'cite thesis' 'geonet3' 'gnis' 'harvard citation no brackets' 'harvnb'
#  'nhle' 'nrisref' 'national heritage list for england' 'soccerbase season'
#  'timatic visa policy' 'cite dvd notes' 'cite interview'
#  'cite mailing list' 'cite newsgroup' 'cite serial' 'cite speech'
#  'cite techreport']

# %%
#Filtering journals
df1 = citations.loc[citations['type_of_citation']=='cite journal']

# %%
#filtering columns
dfnew = df1[['Authors', 'ID_list', 'Title', 'citations', 'id', 'page_title', 'PublisherName']]
dfnew
# Out:
#                                                     Authors  \
# 3777      [{last=Alley, first=Richard B.}, {last=JC Stra...
# 3778      [{link=Joel Mokyr, last=Mokyr, first=Joel\n}, ...
# 3779      [{link=Joel Mokyr, last=Mokyr, first=Joel\n}, ...
# 3780                                                   None
# 3781                             [{last=Falany, first=CN.}]
# ...                                                     ...
# 29181997                                               None
# 29181998      [{link=Peter Suber, last=Suber, first=Peter}]
# 29181999                                               None
# 29182000                [{last=de Souza Ferreira, first=C}]
# 29182001  [{last=Balaji Sitharaman., first=Lalwani, Gaur...
#
#                                                     ID_list  \
# 3777      {ISBN=978-0-8137-2337-2, DOI=10.1130/0-8137-23...
# 3778             {DOI=10.1111/j.1468-0289.1984.tb00344.x\n}
# 3779             {DOI=10.1111/j.1468-0289.1984.tb00344.x\n}
# 3780                                                   None
# 3781        {PMID=9068609, DOI=10.1096/fasebj.11.4.9068609}
# ...                                                     ...
# 29181997                                               None
# 29181998                       {PMID=21602938, PMC=3090178}
# 29181999                                               None
# 29182000     {PMID=26545644, DOI=10.3305/nh.2015.32.5.9394}
# 29182001  {PMID=25788440, PMC=4552611, DOI=10.1002/jbm.a...
#
#                                                       Title  \
# 3777      Glacial processes, past and present: Glaciaolo...
# 3778      New Developments in Irish Population History, ...
# 3779      New Developments in Irish Population History, ...
# 3780                The True Confessions of Charlotte Doyle
# 3781        Enzymology of human cytosolic sulfotransferases
# ...                                                     ...
# 29181997             The Industrialisation of Soviet Russia
# 29181998  An open access mandate for the National Instit...
# 29181999                                     the PWI Awards
# 29182000  Effect of chia seed (Salvia hispanica L.) cons...
# 29182001  Porous three-dimensional carbon nanotube scaff...
#
#                                                   citations        id  \
# 3777      {{Cite journal  | last = Alley  | first =  Ric...  30112151
# 3778      {{Cite journal  | last = Mokyr  | first = Joel...  11693628
# 3779      {{Cite journal  | last = Mokyr  | first = Joel...   1141960
# 3780      {{Cite journal  | last = | first = | title = T...   3057743
# 3781      {{Cite journal  | last1 = Falany | first1 = CN...  29199666
# ...                                                     ...       ...
# 29181997  {{cite journal|year=2004|title=The Industriali...  55744716
# 29181998  {{cite journal|year=2008|title=An open access ...    296002
# 29181999  {{cite journal|year=2014|journal=[[Pro Wrestli...  14203213
# 29182000  {{cite journal|year=2015|title=Effect of chia ...   2768862
# 29182001  {{cite journal|year=2015|title=Porous three-di...   7452926
#
#                                                  page_title  \
# 3777                                          Overdeepening
# 3778                                              Ballitore
# 3779                                               Straffan
# 3780                The True Confessions of Charlotte Doyle
# 3781                          Carbohydrate sulfotransferase
# ...                                                     ...
# 29181997  Excess mortality in the Soviet Union under Jos...
# 29181998                                       Darrell Issa
# 29181999                                       Seth Rollins
# 29182000                                          Chia seed
# 29182001         Potential applications of carbon nanotubes
#
#                           PublisherName
# 3777      Geological Society of America
# 3778                               None
# 3779                               None
# 3780                               None
# 3781                               None
# ...                                 ...
# 29181997             Palgrave Macmillan
# 29181998                           None
# 29181999                           None
# 29182000                           None
# 29182001                           None
#
# [2117505 rows x 7 columns]

# %%
dfnew.nunique()
# Out:
# Authors          1325883
# ID_list          1115732
# Title            1565677
# citations        1911509
# id                521272
# page_title        521272
# PublisherName      45034
# dtype: int64

# %%
#dfdict = dfnew['citations'].str.split('|', expand = True)

# %%
#dfnew.head(1000).to_excel(r'File.xlsx')

# %%
#dfnew[dfnew['citations'].str.contains('journal = ')][1]

# %%
#dfnew['citations'] = dfnew['citations'].astype(str)

# %%
# dfnew['extract'] = dfnew['citations'].str.split('journal =').str[1]
# dfnew['extract']

# %%
dfnew['extract1'] =  dfnew['citations'].str.split('journal =').str[1].str.split('|').str[0]
dfnew['extract2'] =  dfnew['citations'].str.split('journal=').str[1].str.split('|').str[0]
dfnew['extract3']=dfnew['extract1'].combine_first(dfnew['extract2'])
#drop NaN
dfnew = dfnew.dropna(subset=['extract3'])
dfnew
# Out:
# C:\Users\Beka\AppData\Local\Temp\3/ipykernel_11752/1051757761.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfnew['extract1'] =  dfnew['citations'].str.split('journal =').str[1].str.split('|').str[0]
# C:\Users\Beka\AppData\Local\Temp\3/ipykernel_11752/1051757761.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfnew['extract2'] =  dfnew['citations'].str.split('journal=').str[1].str.split('|').str[0]
# C:\Users\Beka\AppData\Local\Temp\3/ipykernel_11752/1051757761.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfnew['extract3']=dfnew['extract1'].combine_first(dfnew['extract2'])
#                                                     Authors  \
# 3777      [{last=Alley, first=Richard B.}, {last=JC Stra...
# 3778      [{link=Joel Mokyr, last=Mokyr, first=Joel\n}, ...
# 3779      [{link=Joel Mokyr, last=Mokyr, first=Joel\n}, ...
# 3780                                                   None
# 3781                             [{last=Falany, first=CN.}]
# ...                                                     ...
# 29181996  [{last=annell, first=LJ}, {last=Taunton, first...
# 29181998      [{link=Peter Suber, last=Suber, first=Peter}]
# 29181999                                               None
# 29182000                [{last=de Souza Ferreira, first=C}]
# 29182001  [{last=Balaji Sitharaman., first=Lalwani, Gaur...
#
#                                                     ID_list  \
# 3777      {ISBN=978-0-8137-2337-2, DOI=10.1130/0-8137-23...
# 3778             {DOI=10.1111/j.1468-0289.1984.tb00344.x\n}
# 3779             {DOI=10.1111/j.1468-0289.1984.tb00344.x\n}
# 3780                                                   None
# 3781        {PMID=9068609, DOI=10.1096/fasebj.11.4.9068609}
# ...                                                     ...
# 29181996  {PMID=11157465, PMC=1724276, DOI=10.1136/bjsm....
# 29181998                       {PMID=21602938, PMC=3090178}
# 29181999                                               None
# 29182000     {PMID=26545644, DOI=10.3305/nh.2015.32.5.9394}
# 29182001  {PMID=25788440, PMC=4552611, DOI=10.1002/jbm.a...
#
#                                                       Title  \
# 3777      Glacial processes, past and present: Glaciaolo...
# 3778      New Developments in Irish Population History, ...
# 3779      New Developments in Irish Population History, ...
# 3780                The True Confessions of Charlotte Doyle
# 3781        Enzymology of human cytosolic sulfotransferases
# ...                                                     ...
# 29181996  A randomised clinical trial of the efficacy of...
# 29181998  An open access mandate for the National Instit...
# 29181999                                     the PWI Awards
# 29182000  Effect of chia seed (Salvia hispanica L.) cons...
# 29182001  Porous three-dimensional carbon nanotube scaff...
#
#                                                   citations        id  \
# 3777      {{Cite journal  | last = Alley  | first =  Ric...  30112151
# 3778      {{Cite journal  | last = Mokyr  | first = Joel...  11693628
# 3779      {{Cite journal  | last = Mokyr  | first = Joel...   1141960
# 3780      {{Cite journal  | last = | first = | title = T...   3057743
# 3781      {{Cite journal  | last1 = Falany | first1 = CN...  29199666
# ...                                                     ...       ...
# 29181996  {{cite journal|year=2001|title=A randomised cl...   1110611
# 29181998  {{cite journal|year=2008|title=An open access ...    296002
# 29181999  {{cite journal|year=2014|journal=[[Pro Wrestli...  14203213
# 29182000  {{cite journal|year=2015|title=Effect of chia ...   2768862
# 29182001  {{cite journal|year=2015|title=Porous three-di...   7452926
#
#                                           page_title  \
# 3777                                   Overdeepening
# 3778                                       Ballitore
# 3779                                        Straffan
# 3780         The True Confessions of Charlotte Doyle
# 3781                   Carbohydrate sulfotransferase
# ...                                              ...
# 29181996                          Muscle contraction
# 29181998                                Darrell Issa
# 29181999                                Seth Rollins
# 29182000                                   Chia seed
# 29182001  Potential applications of carbon nanotubes
#
#                           PublisherName                        extract1  \
# 3777      Geological Society of America             Special Paper 337
# 3778                               None   The Economic History Review
# 3779                               None   The Economic History Review
# 3780                               None    [[The Horn Book Magazine]]
# 3781                               None                        FASEB J
# ...                                 ...                             ...
# 29181996                           None                             NaN
# 29181998                           None                             NaN
# 29181999                           None                             NaN
# 29182000                           None                             NaN
# 29182001                           None                             NaN
#
#                                                  extract2  \
# 3777                                                  NaN
# 3778                                                  NaN
# 3779                                                  NaN
# 3780                                                  NaN
# 3781                                                  NaN
# ...                                                   ...
# 29181996                                  Br J Sports Med
# 29181998                 [[Open Medicine (John Willinsky)
# 29181999                    [[Pro Wrestling Illustrated]]
# 29182000                                        Nutr Hosp
# 29182001  Journal of Biomedical Materials Research Part A
#
#                                                  extract3
# 3777                                  Special Paper 337
# 3778                        The Economic History Review
# 3779                        The Economic History Review
# 3780                         [[The Horn Book Magazine]]
# 3781                                             FASEB J
# ...                                                   ...
# 29181996                                  Br J Sports Med
# 29181998                 [[Open Medicine (John Willinsky)
# 29181999                    [[Pro Wrestling Illustrated]]
# 29182000                                        Nutr Hosp
# 29182001  Journal of Biomedical Materials Research Part A
#
# [2014698 rows x 10 columns]

# %%
#Removing journal and magazine
dfnew['extract4'] =  dfnew['extract3'].str.replace('\(journal\)', '')
dfnew['extract4'] =  dfnew['extract4'].str.replace('\(magazine\)', '')
dfnew
# Out:
# C:\Users\Beka\AppData\Local\Temp\3/ipykernel_11752/2967708168.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   dfnew['extract4'] =  dfnew['extract3'].str.replace('\(journal\)', '')
# C:\Users\Beka\AppData\Local\Temp\3/ipykernel_11752/2967708168.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfnew['extract4'] =  dfnew['extract3'].str.replace('\(journal\)', '')
# C:\Users\Beka\AppData\Local\Temp\3/ipykernel_11752/2967708168.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   dfnew['extract4'] =  dfnew['extract4'].str.replace('\(magazine\)', '')
# C:\Users\Beka\AppData\Local\Temp\3/ipykernel_11752/2967708168.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfnew['extract4'] =  dfnew['extract4'].str.replace('\(magazine\)', '')
#                                                     Authors  \
# 3777      [{last=Alley, first=Richard B.}, {last=JC Stra...
# 3778      [{link=Joel Mokyr, last=Mokyr, first=Joel\n}, ...
# 3779      [{link=Joel Mokyr, last=Mokyr, first=Joel\n}, ...
# 3780                                                   None
# 3781                             [{last=Falany, first=CN.}]
# ...                                                     ...
# 29181996  [{last=annell, first=LJ}, {last=Taunton, first...
# 29181998      [{link=Peter Suber, last=Suber, first=Peter}]
# 29181999                                               None
# 29182000                [{last=de Souza Ferreira, first=C}]
# 29182001  [{last=Balaji Sitharaman., first=Lalwani, Gaur...
#
#                                                     ID_list  \
# 3777      {ISBN=978-0-8137-2337-2, DOI=10.1130/0-8137-23...
# 3778             {DOI=10.1111/j.1468-0289.1984.tb00344.x\n}
# 3779             {DOI=10.1111/j.1468-0289.1984.tb00344.x\n}
# 3780                                                   None
# 3781        {PMID=9068609, DOI=10.1096/fasebj.11.4.9068609}
# ...                                                     ...
# 29181996  {PMID=11157465, PMC=1724276, DOI=10.1136/bjsm....
# 29181998                       {PMID=21602938, PMC=3090178}
# 29181999                                               None
# 29182000     {PMID=26545644, DOI=10.3305/nh.2015.32.5.9394}
# 29182001  {PMID=25788440, PMC=4552611, DOI=10.1002/jbm.a...
#
#                                                       Title  \
# 3777      Glacial processes, past and present: Glaciaolo...
# 3778      New Developments in Irish Population History, ...
# 3779      New Developments in Irish Population History, ...
# 3780                The True Confessions of Charlotte Doyle
# 3781        Enzymology of human cytosolic sulfotransferases
# ...                                                     ...
# 29181996  A randomised clinical trial of the efficacy of...
# 29181998  An open access mandate for the National Instit...
# 29181999                                     the PWI Awards
# 29182000  Effect of chia seed (Salvia hispanica L.) cons...
# 29182001  Porous three-dimensional carbon nanotube scaff...
#
#                                                   citations        id  \
# 3777      {{Cite journal  | last = Alley  | first =  Ric...  30112151
# 3778      {{Cite journal  | last = Mokyr  | first = Joel...  11693628
# 3779      {{Cite journal  | last = Mokyr  | first = Joel...   1141960
# 3780      {{Cite journal  | last = | first = | title = T...   3057743
# 3781      {{Cite journal  | last1 = Falany | first1 = CN...  29199666
# ...                                                     ...       ...
# 29181996  {{cite journal|year=2001|title=A randomised cl...   1110611
# 29181998  {{cite journal|year=2008|title=An open access ...    296002
# 29181999  {{cite journal|year=2014|journal=[[Pro Wrestli...  14203213
# 29182000  {{cite journal|year=2015|title=Effect of chia ...   2768862
# 29182001  {{cite journal|year=2015|title=Porous three-di...   7452926
#
#                                           page_title  \
# 3777                                   Overdeepening
# 3778                                       Ballitore
# 3779                                        Straffan
# 3780         The True Confessions of Charlotte Doyle
# 3781                   Carbohydrate sulfotransferase
# ...                                              ...
# 29181996                          Muscle contraction
# 29181998                                Darrell Issa
# 29181999                                Seth Rollins
# 29182000                                   Chia seed
# 29182001  Potential applications of carbon nanotubes
#
#                           PublisherName                        extract1  \
# 3777      Geological Society of America             Special Paper 337
# 3778                               None   The Economic History Review
# 3779                               None   The Economic History Review
# 3780                               None    [[The Horn Book Magazine]]
# 3781                               None                        FASEB J
# ...                                 ...                             ...
# 29181996                           None                             NaN
# 29181998                           None                             NaN
# 29181999                           None                             NaN
# 29182000                           None                             NaN
# 29182001                           None                             NaN
#
#                                                  extract2  \
# 3777                                                  NaN
# 3778                                                  NaN
# 3779                                                  NaN
# 3780                                                  NaN
# 3781                                                  NaN
# ...                                                   ...
# 29181996                                  Br J Sports Med
# 29181998                 [[Open Medicine (John Willinsky)
# 29181999                    [[Pro Wrestling Illustrated]]
# 29182000                                        Nutr Hosp
# 29182001  Journal of Biomedical Materials Research Part A
#
#                                                  extract3  \
# 3777                                  Special Paper 337
# 3778                        The Economic History Review
# 3779                        The Economic History Review
# 3780                         [[The Horn Book Magazine]]
# 3781                                             FASEB J
# ...                                                   ...
# 29181996                                  Br J Sports Med
# 29181998                 [[Open Medicine (John Willinsky)
# 29181999                    [[Pro Wrestling Illustrated]]
# 29182000                                        Nutr Hosp
# 29182001  Journal of Biomedical Materials Research Part A
#
#                                                  extract4
# 3777                                  Special Paper 337
# 3778                        The Economic History Review
# 3779                        The Economic History Review
# 3780                         [[The Horn Book Magazine]]
# 3781                                             FASEB J
# ...                                                   ...
# 29181996                                  Br J Sports Med
# 29181998                 [[Open Medicine (John Willinsky)
# 29181999                    [[Pro Wrestling Illustrated]]
# 29182000                                        Nutr Hosp
# 29182001  Journal of Biomedical Materials Research Part A
#
# [2014698 rows x 11 columns]

# %%
dfnew['extract4'] =  dfnew['extract4'].str.replace('\[\[', '')
dfnew['extract4'] =  dfnew['extract4'].str.replace('\]\]', '')
dfnew['extract4'] =  dfnew['extract4'].str.replace('\}\}', '')
# Out:
# C:\Users\Beka\AppData\Local\Temp\3/ipykernel_11752/857784551.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   dfnew['extract4'] =  dfnew['extract4'].str.replace('\[\[', '')
# C:\Users\Beka\AppData\Local\Temp\3/ipykernel_11752/857784551.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfnew['extract4'] =  dfnew['extract4'].str.replace('\[\[', '')
# C:\Users\Beka\AppData\Local\Temp\3/ipykernel_11752/857784551.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   dfnew['extract4'] =  dfnew['extract4'].str.replace('\]\]', '')
# C:\Users\Beka\AppData\Local\Temp\3/ipykernel_11752/857784551.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfnew['extract4'] =  dfnew['extract4'].str.replace('\]\]', '')
# C:\Users\Beka\AppData\Local\Temp\3/ipykernel_11752/857784551.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   dfnew['extract4'] =  dfnew['extract4'].str.replace('\}\}', '')
# C:\Users\Beka\AppData\Local\Temp\3/ipykernel_11752/857784551.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfnew['extract4'] =  dfnew['extract4'].str.replace('\}\}', '')

# %%
dfnew
# Out:
#                                                     Authors  \
# 3777      [{last=Alley, first=Richard B.}, {last=JC Stra...
# 3778      [{link=Joel Mokyr, last=Mokyr, first=Joel\n}, ...
# 3779      [{link=Joel Mokyr, last=Mokyr, first=Joel\n}, ...
# 3780                                                   None
# 3781                             [{last=Falany, first=CN.}]
# ...                                                     ...
# 29181996  [{last=annell, first=LJ}, {last=Taunton, first...
# 29181998      [{link=Peter Suber, last=Suber, first=Peter}]
# 29181999                                               None
# 29182000                [{last=de Souza Ferreira, first=C}]
# 29182001  [{last=Balaji Sitharaman., first=Lalwani, Gaur...
#
#                                                     ID_list  \
# 3777      {ISBN=978-0-8137-2337-2, DOI=10.1130/0-8137-23...
# 3778             {DOI=10.1111/j.1468-0289.1984.tb00344.x\n}
# 3779             {DOI=10.1111/j.1468-0289.1984.tb00344.x\n}
# 3780                                                   None
# 3781        {PMID=9068609, DOI=10.1096/fasebj.11.4.9068609}
# ...                                                     ...
# 29181996  {PMID=11157465, PMC=1724276, DOI=10.1136/bjsm....
# 29181998                       {PMID=21602938, PMC=3090178}
# 29181999                                               None
# 29182000     {PMID=26545644, DOI=10.3305/nh.2015.32.5.9394}
# 29182001  {PMID=25788440, PMC=4552611, DOI=10.1002/jbm.a...
#
#                                                       Title  \
# 3777      Glacial processes, past and present: Glaciaolo...
# 3778      New Developments in Irish Population History, ...
# 3779      New Developments in Irish Population History, ...
# 3780                The True Confessions of Charlotte Doyle
# 3781        Enzymology of human cytosolic sulfotransferases
# ...                                                     ...
# 29181996  A randomised clinical trial of the efficacy of...
# 29181998  An open access mandate for the National Instit...
# 29181999                                     the PWI Awards
# 29182000  Effect of chia seed (Salvia hispanica L.) cons...
# 29182001  Porous three-dimensional carbon nanotube scaff...
#
#                                                   citations        id  \
# 3777      {{Cite journal  | last = Alley  | first =  Ric...  30112151
# 3778      {{Cite journal  | last = Mokyr  | first = Joel...  11693628
# 3779      {{Cite journal  | last = Mokyr  | first = Joel...   1141960
# 3780      {{Cite journal  | last = | first = | title = T...   3057743
# 3781      {{Cite journal  | last1 = Falany | first1 = CN...  29199666
# ...                                                     ...       ...
# 29181996  {{cite journal|year=2001|title=A randomised cl...   1110611
# 29181998  {{cite journal|year=2008|title=An open access ...    296002
# 29181999  {{cite journal|year=2014|journal=[[Pro Wrestli...  14203213
# 29182000  {{cite journal|year=2015|title=Effect of chia ...   2768862
# 29182001  {{cite journal|year=2015|title=Porous three-di...   7452926
#
#                                           page_title  \
# 3777                                   Overdeepening
# 3778                                       Ballitore
# 3779                                        Straffan
# 3780         The True Confessions of Charlotte Doyle
# 3781                   Carbohydrate sulfotransferase
# ...                                              ...
# 29181996                          Muscle contraction
# 29181998                                Darrell Issa
# 29181999                                Seth Rollins
# 29182000                                   Chia seed
# 29182001  Potential applications of carbon nanotubes
#
#                           PublisherName                        extract1  \
# 3777      Geological Society of America             Special Paper 337
# 3778                               None   The Economic History Review
# 3779                               None   The Economic History Review
# 3780                               None    [[The Horn Book Magazine]]
# 3781                               None                        FASEB J
# ...                                 ...                             ...
# 29181996                           None                             NaN
# 29181998                           None                             NaN
# 29181999                           None                             NaN
# 29182000                           None                             NaN
# 29182001                           None                             NaN
#
#                                                  extract2  \
# 3777                                                  NaN
# 3778                                                  NaN
# 3779                                                  NaN
# 3780                                                  NaN
# 3781                                                  NaN
# ...                                                   ...
# 29181996                                  Br J Sports Med
# 29181998                 [[Open Medicine (John Willinsky)
# 29181999                    [[Pro Wrestling Illustrated]]
# 29182000                                        Nutr Hosp
# 29182001  Journal of Biomedical Materials Research Part A
#
#                                                  extract3  \
# 3777                                  Special Paper 337
# 3778                        The Economic History Review
# 3779                        The Economic History Review
# 3780                         [[The Horn Book Magazine]]
# 3781                                             FASEB J
# ...                                                   ...
# 29181996                                  Br J Sports Med
# 29181998                 [[Open Medicine (John Willinsky)
# 29181999                    [[Pro Wrestling Illustrated]]
# 29182000                                        Nutr Hosp
# 29182001  Journal of Biomedical Materials Research Part A
#
#                                                  extract4
# 3777                                  Special Paper 337
# 3778                        The Economic History Review
# 3779                        The Economic History Review
# 3780                             The Horn Book Magazine
# 3781                                             FASEB J
# ...                                                   ...
# 29181996                                  Br J Sports Med
# 29181998                   Open Medicine (John Willinsky)
# 29181999                        Pro Wrestling Illustrated
# 29182000                                        Nutr Hosp
# 29182001  Journal of Biomedical Materials Research Part A
#
# [2014698 rows x 11 columns]

# %%
#Deleting white spaces

dfnew['extract4'] =  dfnew['extract4'].replace(r'[^\w\s]+', '', regex=True)
dfnew['extract4'] =  dfnew['extract4'].replace(r'[^\w\s]+', '', regex=True)
dfnew['extract4'] =  dfnew['extract4'].replace('The Journal of Biological Chemistry','Journal of Biological Chemistry')
dfnew['extract4'] =  dfnew['extract4'].replace('J Biol Chem','Journal of Biological Chemistry')
dfnew['extract4'] =  dfnew['extract4'].replace('Proc Natl Acad Sci USA','PNAS')
dfnew['extract4'] =  dfnew['extract4'].replace('Proceedings of the National Academy of Sciences','PNAS')
dfnew['extract4'] =  dfnew['extract4'].replace('Proceedings of the National Academy of Sciences of the United States of America','PNAS')
dfnew['extract4'] =  dfnew['extract4'].replace('PLOS ONE','PLoS ONE')
dfnew['extract4'] =  dfnew['extract4'].replace('PLOS One','PLoS ONE')
dfnew['extract4'] =  dfnew['extract4'].replace('Biochem Biophys Res Commun','Biochemical and Biophysical Research Communications')
dfnew['extract4'] =  dfnew['extract4'].replace('Biochem J','The Biochemical Journal')
dfnew['extract4'] =  dfnew['extract4'].replace('The Lancet','Lancet')
dfnew['extract4'] =  dfnew['extract4'].drop_duplicates()
dfnew['extract4'] =  dfnew['extract4'].str.strip()
dfnew
# Out:
# C:\Users\Beka\AppData\Local\Temp\3/ipykernel_11752/1116924497.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfnew['extract4'] =  dfnew['extract4'].replace(r'[^\w\s]+', '', regex=True)
# C:\Users\Beka\AppData\Local\Temp\3/ipykernel_11752/1116924497.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfnew['extract4'] =  dfnew['extract4'].replace(r'[^\w\s]+', '', regex=True)
# C:\Users\Beka\AppData\Local\Temp\3/ipykernel_11752/1116924497.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfnew['extract4'] =  dfnew['extract4'].replace('The Journal of Biological Chemistry','Journal of Biological Chemistry')
# C:\Users\Beka\AppData\Local\Temp\3/ipykernel_11752/1116924497.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfnew['extract4'] =  dfnew['extract4'].replace('J Biol Chem','Journal of Biological Chemistry')
# C:\Users\Beka\AppData\Local\Temp\3/ipykernel_11752/1116924497.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfnew['extract4'] =  dfnew['extract4'].replace('Proc Natl Acad Sci USA','PNAS')
# C:\Users\Beka\AppData\Local\Temp\3/ipykernel_11752/1116924497.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfnew['extract4'] =  dfnew['extract4'].replace('Proceedings of the National Academy of Sciences','PNAS')
# C:\Users\Beka\AppData\Local\Temp\3/ipykernel_11752/1116924497.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfnew['extract4'] =  dfnew['extract4'].replace('Proceedings of the National Academy of Sciences of the United States of America','PNAS')
# C:\Users\Beka\AppData\Local\Temp\3/ipykernel_11752/1116924497.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfnew['extract4'] =  dfnew['extract4'].replace('PLOS ONE','PLoS ONE')
# C:\Users\Beka\AppData\Local\Temp\3/ipykernel_11752/1116924497.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfnew['extract4'] =  dfnew['extract4'].replace('PLOS One','PLoS ONE')
# C:\Users\Beka\AppData\Local\Temp\3/ipykernel_11752/1116924497.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfnew['extract4'] =  dfnew['extract4'].replace('Biochem Biophys Res Commun','Biochemical and Biophysical Research Communications')
# C:\Users\Beka\AppData\Local\Temp\3/ipykernel_11752/1116924497.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfnew['extract4'] =  dfnew['extract4'].replace('Biochem J','The Biochemical Journal')
# C:\Users\Beka\AppData\Local\Temp\3/ipykernel_11752/1116924497.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfnew['extract4'] =  dfnew['extract4'].replace('The Lancet','Lancet')
# C:\Users\Beka\AppData\Local\Temp\3/ipykernel_11752/1116924497.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfnew['extract4'] =  dfnew['extract4'].drop_duplicates()
# C:\Users\Beka\AppData\Local\Temp\3/ipykernel_11752/1116924497.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfnew['extract4'] =  dfnew['extract4'].str.strip()
#                                                     Authors  \
# 3777      [{last=Alley, first=Richard B.}, {last=JC Stra...
# 3778      [{link=Joel Mokyr, last=Mokyr, first=Joel\n}, ...
# 3779      [{link=Joel Mokyr, last=Mokyr, first=Joel\n}, ...
# 3780                                                   None
# 3781                             [{last=Falany, first=CN.}]
# ...                                                     ...
# 29181996  [{last=annell, first=LJ}, {last=Taunton, first...
# 29181998      [{link=Peter Suber, last=Suber, first=Peter}]
# 29181999                                               None
# 29182000                [{last=de Souza Ferreira, first=C}]
# 29182001  [{last=Balaji Sitharaman., first=Lalwani, Gaur...
#
#                                                     ID_list  \
# 3777      {ISBN=978-0-8137-2337-2, DOI=10.1130/0-8137-23...
# 3778             {DOI=10.1111/j.1468-0289.1984.tb00344.x\n}
# 3779             {DOI=10.1111/j.1468-0289.1984.tb00344.x\n}
# 3780                                                   None
# 3781        {PMID=9068609, DOI=10.1096/fasebj.11.4.9068609}
# ...                                                     ...
# 29181996  {PMID=11157465, PMC=1724276, DOI=10.1136/bjsm....
# 29181998                       {PMID=21602938, PMC=3090178}
# 29181999                                               None
# 29182000     {PMID=26545644, DOI=10.3305/nh.2015.32.5.9394}
# 29182001  {PMID=25788440, PMC=4552611, DOI=10.1002/jbm.a...
#
#                                                       Title  \
# 3777      Glacial processes, past and present: Glaciaolo...
# 3778      New Developments in Irish Population History, ...
# 3779      New Developments in Irish Population History, ...
# 3780                The True Confessions of Charlotte Doyle
# 3781        Enzymology of human cytosolic sulfotransferases
# ...                                                     ...
# 29181996  A randomised clinical trial of the efficacy of...
# 29181998  An open access mandate for the National Instit...
# 29181999                                     the PWI Awards
# 29182000  Effect of chia seed (Salvia hispanica L.) cons...
# 29182001  Porous three-dimensional carbon nanotube scaff...
#
#                                                   citations        id  \
# 3777      {{Cite journal  | last = Alley  | first =  Ric...  30112151
# 3778      {{Cite journal  | last = Mokyr  | first = Joel...  11693628
# 3779      {{Cite journal  | last = Mokyr  | first = Joel...   1141960
# 3780      {{Cite journal  | last = | first = | title = T...   3057743
# 3781      {{Cite journal  | last1 = Falany | first1 = CN...  29199666
# ...                                                     ...       ...
# 29181996  {{cite journal|year=2001|title=A randomised cl...   1110611
# 29181998  {{cite journal|year=2008|title=An open access ...    296002
# 29181999  {{cite journal|year=2014|journal=[[Pro Wrestli...  14203213
# 29182000  {{cite journal|year=2015|title=Effect of chia ...   2768862
# 29182001  {{cite journal|year=2015|title=Porous three-di...   7452926
#
#                                           page_title  \
# 3777                                   Overdeepening
# 3778                                       Ballitore
# 3779                                        Straffan
# 3780         The True Confessions of Charlotte Doyle
# 3781                   Carbohydrate sulfotransferase
# ...                                              ...
# 29181996                          Muscle contraction
# 29181998                                Darrell Issa
# 29181999                                Seth Rollins
# 29182000                                   Chia seed
# 29182001  Potential applications of carbon nanotubes
#
#                           PublisherName                        extract1  \
# 3777      Geological Society of America             Special Paper 337
# 3778                               None   The Economic History Review
# 3779                               None   The Economic History Review
# 3780                               None    [[The Horn Book Magazine]]
# 3781                               None                        FASEB J
# ...                                 ...                             ...
# 29181996                           None                             NaN
# 29181998                           None                             NaN
# 29181999                           None                             NaN
# 29182000                           None                             NaN
# 29182001                           None                             NaN
#
#                                                  extract2  \
# 3777                                                  NaN
# 3778                                                  NaN
# 3779                                                  NaN
# 3780                                                  NaN
# 3781                                                  NaN
# ...                                                   ...
# 29181996                                  Br J Sports Med
# 29181998                 [[Open Medicine (John Willinsky)
# 29181999                    [[Pro Wrestling Illustrated]]
# 29182000                                        Nutr Hosp
# 29182001  Journal of Biomedical Materials Research Part A
#
#                                                  extract3  \
# 3777                                  Special Paper 337
# 3778                        The Economic History Review
# 3779                        The Economic History Review
# 3780                         [[The Horn Book Magazine]]
# 3781                                             FASEB J
# ...                                                   ...
# 29181996                                  Br J Sports Med
# 29181998                 [[Open Medicine (John Willinsky)
# 29181999                    [[Pro Wrestling Illustrated]]
# 29182000                                        Nutr Hosp
# 29182001  Journal of Biomedical Materials Research Part A
#
#                              extract4
# 3777                Special Paper 337
# 3778      The Economic History Review
# 3779                              NaN
# 3780           The Horn Book Magazine
# 3781                          FASEB J
# ...                               ...
# 29181996                          NaN
# 29181998                          NaN
# 29181999                          NaN
# 29182000                          NaN
# 29182001                          NaN
#
# [2014698 rows x 11 columns]

# %%
 dfnew['extract4'].isna().sum()
# Out:
# 0

# %%
# dfnew.to_csv(r'dfnew.csv')

# %%
df_final = dfnew.drop(['extract1', 'extract2', 'extract3'], axis = 1)
df_final = df_final.rename(columns = {'extract4':'journal_name'})
df_final
# Out:
#                                                     Authors  \
# 3777      [{last=Alley, first=Richard B.}, {last=JC Stra...
# 3778      [{link=Joel Mokyr, last=Mokyr, first=Joel\n}, ...
# 3779      [{link=Joel Mokyr, last=Mokyr, first=Joel\n}, ...
# 3780                                                   None
# 3781                             [{last=Falany, first=CN.}]
# ...                                                     ...
# 29181996  [{last=annell, first=LJ}, {last=Taunton, first...
# 29181998      [{link=Peter Suber, last=Suber, first=Peter}]
# 29181999                                               None
# 29182000                [{last=de Souza Ferreira, first=C}]
# 29182001  [{last=Balaji Sitharaman., first=Lalwani, Gaur...
#
#                                                     ID_list  \
# 3777      {ISBN=978-0-8137-2337-2, DOI=10.1130/0-8137-23...
# 3778             {DOI=10.1111/j.1468-0289.1984.tb00344.x\n}
# 3779             {DOI=10.1111/j.1468-0289.1984.tb00344.x\n}
# 3780                                                   None
# 3781        {PMID=9068609, DOI=10.1096/fasebj.11.4.9068609}
# ...                                                     ...
# 29181996  {PMID=11157465, PMC=1724276, DOI=10.1136/bjsm....
# 29181998                       {PMID=21602938, PMC=3090178}
# 29181999                                               None
# 29182000     {PMID=26545644, DOI=10.3305/nh.2015.32.5.9394}
# 29182001  {PMID=25788440, PMC=4552611, DOI=10.1002/jbm.a...
#
#                                                       Title  \
# 3777      Glacial processes, past and present: Glaciaolo...
# 3778      New Developments in Irish Population History, ...
# 3779      New Developments in Irish Population History, ...
# 3780                The True Confessions of Charlotte Doyle
# 3781        Enzymology of human cytosolic sulfotransferases
# ...                                                     ...
# 29181996  A randomised clinical trial of the efficacy of...
# 29181998  An open access mandate for the National Instit...
# 29181999                                     the PWI Awards
# 29182000  Effect of chia seed (Salvia hispanica L.) cons...
# 29182001  Porous three-dimensional carbon nanotube scaff...
#
#                                                   citations        id  \
# 3777      {{Cite journal  | last = Alley  | first =  Ric...  30112151
# 3778      {{Cite journal  | last = Mokyr  | first = Joel...  11693628
# 3779      {{Cite journal  | last = Mokyr  | first = Joel...   1141960
# 3780      {{Cite journal  | last = | first = | title = T...   3057743
# 3781      {{Cite journal  | last1 = Falany | first1 = CN...  29199666
# ...                                                     ...       ...
# 29181996  {{cite journal|year=2001|title=A randomised cl...   1110611
# 29181998  {{cite journal|year=2008|title=An open access ...    296002
# 29181999  {{cite journal|year=2014|journal=[[Pro Wrestli...  14203213
# 29182000  {{cite journal|year=2015|title=Effect of chia ...   2768862
# 29182001  {{cite journal|year=2015|title=Porous three-di...   7452926
#
#                                           page_title  \
# 3777                                   Overdeepening
# 3778                                       Ballitore
# 3779                                        Straffan
# 3780         The True Confessions of Charlotte Doyle
# 3781                   Carbohydrate sulfotransferase
# ...                                              ...
# 29181996                          Muscle contraction
# 29181998                                Darrell Issa
# 29181999                                Seth Rollins
# 29182000                                   Chia seed
# 29182001  Potential applications of carbon nanotubes
#
#                           PublisherName  \
# 3777      Geological Society of America
# 3778                               None
# 3779                               None
# 3780                               None
# 3781                               None
# ...                                 ...
# 29181996                           None
# 29181998                           None
# 29181999                           None
# 29182000                           None
# 29182001                           None
#
#                                              journal_name
# 3777                                  Special Paper 337
# 3778                        The Economic History Review
# 3779                        The Economic History Review
# 3780                             The Horn Book Magazine
# 3781                                             FASEB J
# ...                                                   ...
# 29181996                                  Br J Sports Med
# 29181998                   Open Medicine (John Willinsky)
# 29181999                        Pro Wrestling Illustrated
# 29182000                                        Nutr Hosp
# 29182001  Journal of Biomedical Materials Research Part A
#
# [2014698 rows x 8 columns]

# %%
#Deleting white spaces
df_final['journal_name'] = df_final['journal_name'].replace(r'[^\w\s]+', '', regex=True)


df_final['journal_name'] = df_final['journal_name'].str.lower()
df_final['journal_name'] = df_final['journal_name'].str.strip()
df_final['page_title'] = df_final['page_title'].str.lower()
df_final['page_title'] = df_final['page_title'].str.strip()
df_final = df_final.replace('the journal of biological chemistry','journal of biological chemistry')
df_final = df_final.replace('j biol chem','journal of biological chemistry')
df_final = df_final.replace('proc natl acad sci usa','pnas')
df_final = df_final.replace('proceedings of the national academy of sciences','pnas')
df_final = df_final.replace('proceedings of the national academy of sciences of the united states of america','pnas')
df_final = df_final.replace('biochem biophys res Commun','biochemical and biophysical research communications')
df_final = df_final.replace('biochem j','the biochemical journal')
df_final = df_final.replace('the lancet','lancet')
df_final = df_final.drop_duplicates()
df_final
# Out:
#                                                     Authors  \
# 3777      [{last=Alley, first=Richard B.}, {last=JC Stra...
# 3778      [{link=Joel Mokyr, last=Mokyr, first=Joel\n}, ...
# 3779      [{link=Joel Mokyr, last=Mokyr, first=Joel\n}, ...
# 3780                                                   None
# 3781                             [{last=Falany, first=CN.}]
# ...                                                     ...
# 29181996  [{last=annell, first=LJ}, {last=Taunton, first...
# 29181998      [{link=Peter Suber, last=Suber, first=Peter}]
# 29181999                                               None
# 29182000                [{last=de Souza Ferreira, first=C}]
# 29182001  [{last=Balaji Sitharaman., first=Lalwani, Gaur...
#
#                                                     ID_list  \
# 3777      {ISBN=978-0-8137-2337-2, DOI=10.1130/0-8137-23...
# 3778             {DOI=10.1111/j.1468-0289.1984.tb00344.x\n}
# 3779             {DOI=10.1111/j.1468-0289.1984.tb00344.x\n}
# 3780                                                   None
# 3781        {PMID=9068609, DOI=10.1096/fasebj.11.4.9068609}
# ...                                                     ...
# 29181996  {PMID=11157465, PMC=1724276, DOI=10.1136/bjsm....
# 29181998                       {PMID=21602938, PMC=3090178}
# 29181999                                               None
# 29182000     {PMID=26545644, DOI=10.3305/nh.2015.32.5.9394}
# 29182001  {PMID=25788440, PMC=4552611, DOI=10.1002/jbm.a...
#
#                                                       Title  \
# 3777      Glacial processes, past and present: Glaciaolo...
# 3778      New Developments in Irish Population History, ...
# 3779      New Developments in Irish Population History, ...
# 3780                The True Confessions of Charlotte Doyle
# 3781        Enzymology of human cytosolic sulfotransferases
# ...                                                     ...
# 29181996  A randomised clinical trial of the efficacy of...
# 29181998  An open access mandate for the National Instit...
# 29181999                                     the PWI Awards
# 29182000  Effect of chia seed (Salvia hispanica L.) cons...
# 29182001  Porous three-dimensional carbon nanotube scaff...
#
#                                                   citations        id  \
# 3777      {{Cite journal  | last = Alley  | first =  Ric...  30112151
# 3778      {{Cite journal  | last = Mokyr  | first = Joel...  11693628
# 3779      {{Cite journal  | last = Mokyr  | first = Joel...   1141960
# 3780      {{Cite journal  | last = | first = | title = T...   3057743
# 3781      {{Cite journal  | last1 = Falany | first1 = CN...  29199666
# ...                                                     ...       ...
# 29181996  {{cite journal|year=2001|title=A randomised cl...   1110611
# 29181998  {{cite journal|year=2008|title=An open access ...    296002
# 29181999  {{cite journal|year=2014|journal=[[Pro Wrestli...  14203213
# 29182000  {{cite journal|year=2015|title=Effect of chia ...   2768862
# 29182001  {{cite journal|year=2015|title=Porous three-di...   7452926
#
#                                           page_title  \
# 3777                                   overdeepening
# 3778                                       ballitore
# 3779                                        straffan
# 3780         the true confessions of charlotte doyle
# 3781                   carbohydrate sulfotransferase
# ...                                              ...
# 29181996                          muscle contraction
# 29181998                                darrell issa
# 29181999                                seth rollins
# 29182000                                   chia seed
# 29182001  potential applications of carbon nanotubes
#
#                           PublisherName  \
# 3777      Geological Society of America
# 3778                               None
# 3779                               None
# 3780                               None
# 3781                               None
# ...                                 ...
# 29181996                           None
# 29181998                           None
# 29181999                           None
# 29182000                           None
# 29182001                           None
#
#                                              journal_name
# 3777                                    special paper 337
# 3778                          the economic history review
# 3779                          the economic history review
# 3780                               the horn book magazine
# 3781                                              faseb j
# ...                                                   ...
# 29181996                                  br j sports med
# 29181998                     open medicine john willinsky
# 29181999                        pro wrestling illustrated
# 29182000                                        nutr hosp
# 29182001  journal of biomedical materials research part a
#
# [1996721 rows x 8 columns]

# %%
 df_final['journal_name'].isna().sum()
# Out:
# 0

# %%
# df_final.to_csv(r'df_final.csv')

# %%
df_final.columns
# Out:
# Index(['Authors', 'ID_list', 'Title', 'citations', 'id', 'page_title',
#        'PublisherName', 'journal_name'],
#       dtype='object')

# %%
df_journal = df_final[['page_title', 'journal_name']]

# %%
df_journal
# Out:
#                                           page_title  \
# 3777                                   overdeepening
# 3778                                       ballitore
# 3779                                        straffan
# 3780         the true confessions of charlotte doyle
# 3781                   carbohydrate sulfotransferase
# ...                                              ...
# 29181996                          muscle contraction
# 29181998                                darrell issa
# 29181999                                seth rollins
# 29182000                                   chia seed
# 29182001  potential applications of carbon nanotubes
#
#                                              journal_name
# 3777                                    special paper 337
# 3778                          the economic history review
# 3779                          the economic history review
# 3780                               the horn book magazine
# 3781                                              faseb j
# ...                                                   ...
# 29181996                                  br j sports med
# 29181998                     open medicine john willinsky
# 29181999                        pro wrestling illustrated
# 29182000                                        nutr hosp
# 29182001  journal of biomedical materials research part a
#
# [1996721 rows x 2 columns]

# %%
df_journal.to_csv(r'df_journal.csv', index = False)

# %%
df_journal = df_journal.sort_values(by=['journal_name'], ascending=False)
df_journal
# Out:
#                                                  page_title journal_name
# 10584885                                          paradroid       zzap64
# 15264733                             little computer people       zzap64
# 4438937                              spindizzy (video game)       zzap64
# 14680933                           blood money (video game)       zzap64
# 2238017                                   sdi (arcade game)       zzap64
# ...                                                     ...          ...
# 2831196   grammy award for best female rap solo performance
# 24638101                             gender and development
# 28152803                             frank thompson (coach)
# 14491591                                 quran and miracles
# 10590213                                  labour party (uk)
#
# [1996721 rows x 2 columns]

# %%
df_journal['journal_name'].isna().sum()
# Out:
# 0
