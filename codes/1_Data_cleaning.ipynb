# %%
#!pip install -r Requirements.txt

# %%
#!pip install pyarrow

# %%
## All imports
import nltk
import numpy as np
import pandas as pd
import networkx as nx
import seaborn as sns
from tqdm import tqdm
from collections import Counter
import matplotlib.pyplot as plt

# %%
INPUT_DATA = 'C:\\Users\\Beka\\Downloads\\citations_from_wikipedia\\dataset.parquet'

# %%
## Reading the dataset
citations = pd.read_parquet(INPUT_DATA)
print('Total number of rows in the whole dataset: {}'.format(citations.count()))
# Out:
# Total number of rows in the whole dataset: AccessDate              134324
# Authors               11854817
# Chapter                 350551
# Chron                   135156
# City                         7
# Date                  17152154
# Degree                    4953
# Edition                 292512
# Encyclopedia             55592
# Format                  264685
# ID_list                3928392
# Issue                  1692004
# Pages                  4639675
# Periodical            14491903
# PublicationPlace       2127304
# PublisherName         12900448
# Series                  249148
# SeriesNumber          16053666
# Title                 28753918
# TitleType               175416
# URL                   24956769
# Volume                 1990887
# citations             29276667
# id                    29276667
# page_title            29276667
# r_id                  29276667
# r_parentid            29237202
# sections              29276667
# type_of_citation      29276667
# metadata_file           262909
# updated_identifier      262909
# conf_score              262909
# dtype: int64

# %%
print(citations["type_of_citation"].unique())
# Out:
# ['citation' 'cite av media notes' 'cite av media' 'cite book'
#  'cite episode' 'cite gnis' 'cite news' 'cite sports-reference' 'cite web'
#  'cite arxiv' 'cite conference' 'cite encyclopedia' 'cite journal'
#  'cite map' 'cite podcast' 'cite press release' 'cite report' 'cite sign'
#  'cite thesis' 'geonet3' 'gnis' 'harvard citation no brackets' 'harvnb'
#  'nhle' 'nrisref' 'national heritage list for england' 'soccerbase season'
#  'timatic visa policy' 'cite dvd notes' 'cite interview'
#  'cite mailing list' 'cite newsgroup' 'cite serial' 'cite speech'
#  'cite techreport']

# %%
#Filtering journals
df1 = citations.loc[citations['type_of_citation']=='cite journal']

# %%
#filtering columns
dfnew = df1[['Authors', 'ID_list', 'Title', 'citations', 'id', 'page_title', 'PublisherName']]
dfnew
# Out:
#                                                     Authors  \
# 3777      [{last=Alley, first=Richard B.}, {last=JC Stra...
# 3778      [{link=Joel Mokyr, last=Mokyr, first=Joel\n}, ...
# 3779      [{link=Joel Mokyr, last=Mokyr, first=Joel\n}, ...
# 3780                                                   None
# 3781                             [{last=Falany, first=CN.}]
# ...                                                     ...
# 29181997                                               None
# 29181998      [{link=Peter Suber, last=Suber, first=Peter}]
# 29181999                                               None
# 29182000                [{last=de Souza Ferreira, first=C}]
# 29182001  [{last=Balaji Sitharaman., first=Lalwani, Gaur...
#
#                                                     ID_list  \
# 3777      {ISBN=978-0-8137-2337-2, DOI=10.1130/0-8137-23...
# 3778             {DOI=10.1111/j.1468-0289.1984.tb00344.x\n}
# 3779             {DOI=10.1111/j.1468-0289.1984.tb00344.x\n}
# 3780                                                   None
# 3781        {PMID=9068609, DOI=10.1096/fasebj.11.4.9068609}
# ...                                                     ...
# 29181997                                               None
# 29181998                       {PMID=21602938, PMC=3090178}
# 29181999                                               None
# 29182000     {PMID=26545644, DOI=10.3305/nh.2015.32.5.9394}
# 29182001  {PMID=25788440, PMC=4552611, DOI=10.1002/jbm.a...
#
#                                                       Title  \
# 3777      Glacial processes, past and present: Glaciaolo...
# 3778      New Developments in Irish Population History, ...
# 3779      New Developments in Irish Population History, ...
# 3780                The True Confessions of Charlotte Doyle
# 3781        Enzymology of human cytosolic sulfotransferases
# ...                                                     ...
# 29181997             The Industrialisation of Soviet Russia
# 29181998  An open access mandate for the National Instit...
# 29181999                                     the PWI Awards
# 29182000  Effect of chia seed (Salvia hispanica L.) cons...
# 29182001  Porous three-dimensional carbon nanotube scaff...
#
#                                                   citations        id  \
# 3777      {{Cite journal  | last = Alley  | first =  Ric...  30112151
# 3778      {{Cite journal  | last = Mokyr  | first = Joel...  11693628
# 3779      {{Cite journal  | last = Mokyr  | first = Joel...   1141960
# 3780      {{Cite journal  | last = | first = | title = T...   3057743
# 3781      {{Cite journal  | last1 = Falany | first1 = CN...  29199666
# ...                                                     ...       ...
# 29181997  {{cite journal|year=2004|title=The Industriali...  55744716
# 29181998  {{cite journal|year=2008|title=An open access ...    296002
# 29181999  {{cite journal|year=2014|journal=[[Pro Wrestli...  14203213
# 29182000  {{cite journal|year=2015|title=Effect of chia ...   2768862
# 29182001  {{cite journal|year=2015|title=Porous three-di...   7452926
#
#                                                  page_title  \
# 3777                                          Overdeepening
# 3778                                              Ballitore
# 3779                                               Straffan
# 3780                The True Confessions of Charlotte Doyle
# 3781                          Carbohydrate sulfotransferase
# ...                                                     ...
# 29181997  Excess mortality in the Soviet Union under Jos...
# 29181998                                       Darrell Issa
# 29181999                                       Seth Rollins
# 29182000                                          Chia seed
# 29182001         Potential applications of carbon nanotubes
#
#                           PublisherName
# 3777      Geological Society of America
# 3778                               None
# 3779                               None
# 3780                               None
# 3781                               None
# ...                                 ...
# 29181997             Palgrave Macmillan
# 29181998                           None
# 29181999                           None
# 29182000                           None
# 29182001                           None
#
# [2117505 rows x 7 columns]

# %%
dfnew.nunique()
# Out:
# Authors          1293850
# ID_list          1105285
# Title            1492381
# citations        1815931
# id                486799
# page_title        486799
# PublisherName      32689
# extract1           71494
# extract2          253606
# extract3          310156
# extract4          188632
# dtype: int64

# %%
#dfdict = dfnew['citations'].str.split('|', expand = True)

# %%
#dfnew.head(1000).to_excel(r'File.xlsx')

# %%
#dfnew[dfnew['citations'].str.contains('journal = ')][1]

# %%
#dfnew['citations'] = dfnew['citations'].astype(str)
# Out:
# C:\Users\Beka\AppData\Local\Temp\5/ipykernel_29588/1482911200.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfnew['citations'] = dfnew['citations'].astype(str)

# %%
dfnew['extract'] = dfnew['citations'].str.split('journal =').str[1]
dfnew['extract']
# Out:
# C:\Users\Beka\AppData\Local\Temp\5/ipykernel_29588/3830949700.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfnew['extract'] = dfnew['citations'].str.split('journal =').str[1]
# 3777         Special Paper 337  | volume =   | issue =   |...
# 3778         The Economic History Review  | volume =  37  ...
# 3779         The Economic History Review  | volume =  37  ...
# 3780         [[The Horn Book Magazine]]  | volbonerume =  ...
# 3781         FASEB J | volume = 11 | issue = 4 | pages = 2...
#                                   ...
# 29181997                                                  NaN
# 29181998                                                  NaN
# 29181999                                                  NaN
# 29182000                                                  NaN
# 29182001                                                  NaN
# Name: extract, Length: 2117505, dtype: object

# %%
dfnew['extract1'] =  dfnew['citations'].str.split('journal =').str[1].str.split('|').str[0]
dfnew['extract2'] =  dfnew['citations'].str.split('journal=').str[1].str.split('|').str[0]
dfnew['extract3']=dfnew['extract1'].combine_first(dfnew['extract2'])
dfnew
# Out:
# C:\Users\Beka\AppData\Local\Temp\5/ipykernel_29588/1477229317.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfnew['extract1'] =  dfnew['citations'].str.split('journal =').str[1].str.split('|').str[0]
# C:\Users\Beka\AppData\Local\Temp\5/ipykernel_29588/1477229317.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfnew['extract2'] =  dfnew['citations'].str.split('journal=').str[1].str.split('|').str[0]
# C:\Users\Beka\AppData\Local\Temp\5/ipykernel_29588/1477229317.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfnew['extract3']=dfnew['extract1'].combine_first(dfnew['extract2'])
#                                                     Authors  \
# 3777      [{last=Alley, first=Richard B.}, {last=JC Stra...
# 3778      [{link=Joel Mokyr, last=Mokyr, first=Joel\n}, ...
# 3779      [{link=Joel Mokyr, last=Mokyr, first=Joel\n}, ...
# 3780                                                   None
# 3781                             [{last=Falany, first=CN.}]
# ...                                                     ...
# 29181997                                               None
# 29181998      [{link=Peter Suber, last=Suber, first=Peter}]
# 29181999                                               None
# 29182000                [{last=de Souza Ferreira, first=C}]
# 29182001  [{last=Balaji Sitharaman., first=Lalwani, Gaur...
#
#                                                     ID_list  \
# 3777      {ISBN=978-0-8137-2337-2, DOI=10.1130/0-8137-23...
# 3778             {DOI=10.1111/j.1468-0289.1984.tb00344.x\n}
# 3779             {DOI=10.1111/j.1468-0289.1984.tb00344.x\n}
# 3780                                                   None
# 3781        {PMID=9068609, DOI=10.1096/fasebj.11.4.9068609}
# ...                                                     ...
# 29181997                                               None
# 29181998                       {PMID=21602938, PMC=3090178}
# 29181999                                               None
# 29182000     {PMID=26545644, DOI=10.3305/nh.2015.32.5.9394}
# 29182001  {PMID=25788440, PMC=4552611, DOI=10.1002/jbm.a...
#
#                                                       Title  \
# 3777      Glacial processes, past and present: Glaciaolo...
# 3778      New Developments in Irish Population History, ...
# 3779      New Developments in Irish Population History, ...
# 3780                The True Confessions of Charlotte Doyle
# 3781        Enzymology of human cytosolic sulfotransferases
# ...                                                     ...
# 29181997             The Industrialisation of Soviet Russia
# 29181998  An open access mandate for the National Instit...
# 29181999                                     the PWI Awards
# 29182000  Effect of chia seed (Salvia hispanica L.) cons...
# 29182001  Porous three-dimensional carbon nanotube scaff...
#
#                                                   citations        id  \
# 3777      {{Cite journal  | last = Alley  | first =  Ric...  30112151
# 3778      {{Cite journal  | last = Mokyr  | first = Joel...  11693628
# 3779      {{Cite journal  | last = Mokyr  | first = Joel...   1141960
# 3780      {{Cite journal  | last = | first = | title = T...   3057743
# 3781      {{Cite journal  | last1 = Falany | first1 = CN...  29199666
# ...                                                     ...       ...
# 29181997  {{cite journal|year=2004|title=The Industriali...  55744716
# 29181998  {{cite journal|year=2008|title=An open access ...    296002
# 29181999  {{cite journal|year=2014|journal=[[Pro Wrestli...  14203213
# 29182000  {{cite journal|year=2015|title=Effect of chia ...   2768862
# 29182001  {{cite journal|year=2015|title=Porous three-di...   7452926
#
#                                                  page_title  \
# 3777                                          Overdeepening
# 3778                                              Ballitore
# 3779                                               Straffan
# 3780                The True Confessions of Charlotte Doyle
# 3781                          Carbohydrate sulfotransferase
# ...                                                     ...
# 29181997  Excess mortality in the Soviet Union under Jos...
# 29181998                                       Darrell Issa
# 29181999                                       Seth Rollins
# 29182000                                          Chia seed
# 29182001         Potential applications of carbon nanotubes
#
#                           PublisherName                        extract1  \
# 3777      Geological Society of America             Special Paper 337
# 3778                               None   The Economic History Review
# 3779                               None   The Economic History Review
# 3780                               None    [[The Horn Book Magazine]]
# 3781                               None                        FASEB J
# ...                                 ...                             ...
# 29181997             Palgrave Macmillan                             NaN
# 29181998                           None                             NaN
# 29181999                           None                             NaN
# 29182000                           None                             NaN
# 29182001                           None                             NaN
#
#                                                  extract2  \
# 3777                                                  NaN
# 3778                                                  NaN
# 3779                                                  NaN
# 3780                                                  NaN
# 3781                                                  NaN
# ...                                                   ...
# 29181997                                              NaN
# 29181998                 [[Open Medicine (John Willinsky)
# 29181999                    [[Pro Wrestling Illustrated]]
# 29182000                                        Nutr Hosp
# 29182001  Journal of Biomedical Materials Research Part A
#
#                                                  extract3
# 3777                                  Special Paper 337
# 3778                        The Economic History Review
# 3779                        The Economic History Review
# 3780                         [[The Horn Book Magazine]]
# 3781                                             FASEB J
# ...                                                   ...
# 29181997                                              NaN
# 29181998                 [[Open Medicine (John Willinsky)
# 29181999                    [[Pro Wrestling Illustrated]]
# 29182000                                        Nutr Hosp
# 29182001  Journal of Biomedical Materials Research Part A
#
# [2117505 rows x 10 columns]

# %%
#drop NaN
dfnew = dfnew.dropna(subset=['extract3'])
dfnew
# Out:
#                                                     Authors  \
# 3777      [{last=Alley, first=Richard B.}, {last=JC Stra...
# 3778      [{link=Joel Mokyr, last=Mokyr, first=Joel\n}, ...
# 3779      [{link=Joel Mokyr, last=Mokyr, first=Joel\n}, ...
# 3780                                                   None
# 3781                             [{last=Falany, first=CN.}]
# ...                                                     ...
# 29181996  [{last=annell, first=LJ}, {last=Taunton, first...
# 29181998      [{link=Peter Suber, last=Suber, first=Peter}]
# 29181999                                               None
# 29182000                [{last=de Souza Ferreira, first=C}]
# 29182001  [{last=Balaji Sitharaman., first=Lalwani, Gaur...
#
#                                                     ID_list  \
# 3777      {ISBN=978-0-8137-2337-2, DOI=10.1130/0-8137-23...
# 3778             {DOI=10.1111/j.1468-0289.1984.tb00344.x\n}
# 3779             {DOI=10.1111/j.1468-0289.1984.tb00344.x\n}
# 3780                                                   None
# 3781        {PMID=9068609, DOI=10.1096/fasebj.11.4.9068609}
# ...                                                     ...
# 29181996  {PMID=11157465, PMC=1724276, DOI=10.1136/bjsm....
# 29181998                       {PMID=21602938, PMC=3090178}
# 29181999                                               None
# 29182000     {PMID=26545644, DOI=10.3305/nh.2015.32.5.9394}
# 29182001  {PMID=25788440, PMC=4552611, DOI=10.1002/jbm.a...
#
#                                                       Title  \
# 3777      Glacial processes, past and present: Glaciaolo...
# 3778      New Developments in Irish Population History, ...
# 3779      New Developments in Irish Population History, ...
# 3780                The True Confessions of Charlotte Doyle
# 3781        Enzymology of human cytosolic sulfotransferases
# ...                                                     ...
# 29181996  A randomised clinical trial of the efficacy of...
# 29181998  An open access mandate for the National Instit...
# 29181999                                     the PWI Awards
# 29182000  Effect of chia seed (Salvia hispanica L.) cons...
# 29182001  Porous three-dimensional carbon nanotube scaff...
#
#                                                   citations        id  \
# 3777      {{Cite journal  | last = Alley  | first =  Ric...  30112151
# 3778      {{Cite journal  | last = Mokyr  | first = Joel...  11693628
# 3779      {{Cite journal  | last = Mokyr  | first = Joel...   1141960
# 3780      {{Cite journal  | last = | first = | title = T...   3057743
# 3781      {{Cite journal  | last1 = Falany | first1 = CN...  29199666
# ...                                                     ...       ...
# 29181996  {{cite journal|year=2001|title=A randomised cl...   1110611
# 29181998  {{cite journal|year=2008|title=An open access ...    296002
# 29181999  {{cite journal|year=2014|journal=[[Pro Wrestli...  14203213
# 29182000  {{cite journal|year=2015|title=Effect of chia ...   2768862
# 29182001  {{cite journal|year=2015|title=Porous three-di...   7452926
#
#                                           page_title  \
# 3777                                   Overdeepening
# 3778                                       Ballitore
# 3779                                        Straffan
# 3780         The True Confessions of Charlotte Doyle
# 3781                   Carbohydrate sulfotransferase
# ...                                              ...
# 29181996                          Muscle contraction
# 29181998                                Darrell Issa
# 29181999                                Seth Rollins
# 29182000                                   Chia seed
# 29182001  Potential applications of carbon nanotubes
#
#                           PublisherName                        extract1  \
# 3777      Geological Society of America             Special Paper 337
# 3778                               None   The Economic History Review
# 3779                               None   The Economic History Review
# 3780                               None    [[The Horn Book Magazine]]
# 3781                               None                        FASEB J
# ...                                 ...                             ...
# 29181996                           None                             NaN
# 29181998                           None                             NaN
# 29181999                           None                             NaN
# 29182000                           None                             NaN
# 29182001                           None                             NaN
#
#                                                  extract2  \
# 3777                                                  NaN
# 3778                                                  NaN
# 3779                                                  NaN
# 3780                                                  NaN
# 3781                                                  NaN
# ...                                                   ...
# 29181996                                  Br J Sports Med
# 29181998                 [[Open Medicine (John Willinsky)
# 29181999                    [[Pro Wrestling Illustrated]]
# 29182000                                        Nutr Hosp
# 29182001  Journal of Biomedical Materials Research Part A
#
#                                                  extract3
# 3777                                  Special Paper 337
# 3778                        The Economic History Review
# 3779                        The Economic History Review
# 3780                         [[The Horn Book Magazine]]
# 3781                                             FASEB J
# ...                                                   ...
# 29181996                                  Br J Sports Med
# 29181998                 [[Open Medicine (John Willinsky)
# 29181999                    [[Pro Wrestling Illustrated]]
# 29182000                                        Nutr Hosp
# 29182001  Journal of Biomedical Materials Research Part A
#
# [2014698 rows x 10 columns]

# %%
#Removing journal and magazine
dfnew['extract4'] =  dfnew['extract3'].str.replace('\(journal\)', '')
dfnew['extract4'] =  dfnew['extract4'].str.replace('\(magazine\)', '')
dfnew
# Out:
# C:\Users\Beka\AppData\Local\Temp\5/ipykernel_29588/2967708168.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   dfnew['extract4'] =  dfnew['extract3'].str.replace('\(journal\)', '')
# C:\Users\Beka\AppData\Local\Temp\5/ipykernel_29588/2967708168.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfnew['extract4'] =  dfnew['extract3'].str.replace('\(journal\)', '')
# C:\Users\Beka\AppData\Local\Temp\5/ipykernel_29588/2967708168.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   dfnew['extract4'] =  dfnew['extract4'].str.replace('\(magazine\)', '')
# C:\Users\Beka\AppData\Local\Temp\5/ipykernel_29588/2967708168.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfnew['extract4'] =  dfnew['extract4'].str.replace('\(magazine\)', '')
#                                                     Authors  \
# 3777      [{last=Alley, first=Richard B.}, {last=JC Stra...
# 3778      [{link=Joel Mokyr, last=Mokyr, first=Joel\n}, ...
# 3779      [{link=Joel Mokyr, last=Mokyr, first=Joel\n}, ...
# 3780                                                   None
# 3781                             [{last=Falany, first=CN.}]
# ...                                                     ...
# 29181996  [{last=annell, first=LJ}, {last=Taunton, first...
# 29181998      [{link=Peter Suber, last=Suber, first=Peter}]
# 29181999                                               None
# 29182000                [{last=de Souza Ferreira, first=C}]
# 29182001  [{last=Balaji Sitharaman., first=Lalwani, Gaur...
#
#                                                     ID_list  \
# 3777      {ISBN=978-0-8137-2337-2, DOI=10.1130/0-8137-23...
# 3778             {DOI=10.1111/j.1468-0289.1984.tb00344.x\n}
# 3779             {DOI=10.1111/j.1468-0289.1984.tb00344.x\n}
# 3780                                                   None
# 3781        {PMID=9068609, DOI=10.1096/fasebj.11.4.9068609}
# ...                                                     ...
# 29181996  {PMID=11157465, PMC=1724276, DOI=10.1136/bjsm....
# 29181998                       {PMID=21602938, PMC=3090178}
# 29181999                                               None
# 29182000     {PMID=26545644, DOI=10.3305/nh.2015.32.5.9394}
# 29182001  {PMID=25788440, PMC=4552611, DOI=10.1002/jbm.a...
#
#                                                       Title  \
# 3777      Glacial processes, past and present: Glaciaolo...
# 3778      New Developments in Irish Population History, ...
# 3779      New Developments in Irish Population History, ...
# 3780                The True Confessions of Charlotte Doyle
# 3781        Enzymology of human cytosolic sulfotransferases
# ...                                                     ...
# 29181996  A randomised clinical trial of the efficacy of...
# 29181998  An open access mandate for the National Instit...
# 29181999                                     the PWI Awards
# 29182000  Effect of chia seed (Salvia hispanica L.) cons...
# 29182001  Porous three-dimensional carbon nanotube scaff...
#
#                                                   citations        id  \
# 3777      {{Cite journal  | last = Alley  | first =  Ric...  30112151
# 3778      {{Cite journal  | last = Mokyr  | first = Joel...  11693628
# 3779      {{Cite journal  | last = Mokyr  | first = Joel...   1141960
# 3780      {{Cite journal  | last = | first = | title = T...   3057743
# 3781      {{Cite journal  | last1 = Falany | first1 = CN...  29199666
# ...                                                     ...       ...
# 29181996  {{cite journal|year=2001|title=A randomised cl...   1110611
# 29181998  {{cite journal|year=2008|title=An open access ...    296002
# 29181999  {{cite journal|year=2014|journal=[[Pro Wrestli...  14203213
# 29182000  {{cite journal|year=2015|title=Effect of chia ...   2768862
# 29182001  {{cite journal|year=2015|title=Porous three-di...   7452926
#
#                                           page_title  \
# 3777                                   Overdeepening
# 3778                                       Ballitore
# 3779                                        Straffan
# 3780         The True Confessions of Charlotte Doyle
# 3781                   Carbohydrate sulfotransferase
# ...                                              ...
# 29181996                          Muscle contraction
# 29181998                                Darrell Issa
# 29181999                                Seth Rollins
# 29182000                                   Chia seed
# 29182001  Potential applications of carbon nanotubes
#
#                           PublisherName                        extract1  \
# 3777      Geological Society of America             Special Paper 337
# 3778                               None   The Economic History Review
# 3779                               None   The Economic History Review
# 3780                               None    [[The Horn Book Magazine]]
# 3781                               None                        FASEB J
# ...                                 ...                             ...
# 29181996                           None                             NaN
# 29181998                           None                             NaN
# 29181999                           None                             NaN
# 29182000                           None                             NaN
# 29182001                           None                             NaN
#
#                                                  extract2  \
# 3777                                                  NaN
# 3778                                                  NaN
# 3779                                                  NaN
# 3780                                                  NaN
# 3781                                                  NaN
# ...                                                   ...
# 29181996                                  Br J Sports Med
# 29181998                 [[Open Medicine (John Willinsky)
# 29181999                    [[Pro Wrestling Illustrated]]
# 29182000                                        Nutr Hosp
# 29182001  Journal of Biomedical Materials Research Part A
#
#                                                  extract3  \
# 3777                                  Special Paper 337
# 3778                        The Economic History Review
# 3779                        The Economic History Review
# 3780                         [[The Horn Book Magazine]]
# 3781                                             FASEB J
# ...                                                   ...
# 29181996                                  Br J Sports Med
# 29181998                 [[Open Medicine (John Willinsky)
# 29181999                    [[Pro Wrestling Illustrated]]
# 29182000                                        Nutr Hosp
# 29182001  Journal of Biomedical Materials Research Part A
#
#                                                  extract4
# 3777                                  Special Paper 337
# 3778                        The Economic History Review
# 3779                        The Economic History Review
# 3780                         [[The Horn Book Magazine]]
# 3781                                             FASEB J
# ...                                                   ...
# 29181996                                  Br J Sports Med
# 29181998                 [[Open Medicine (John Willinsky)
# 29181999                    [[Pro Wrestling Illustrated]]
# 29182000                                        Nutr Hosp
# 29182001  Journal of Biomedical Materials Research Part A
#
# [2014698 rows x 11 columns]

# %%
dfnew['extract4'] =  dfnew['extract4'].str.replace('\[\[', '')
dfnew['extract4'] =  dfnew['extract4'].str.replace('\]\]', '')
dfnew['extract4'] =  dfnew['extract4'].str.replace('\}\}', '')
# Out:
# C:\Users\Beka\AppData\Local\Temp\5/ipykernel_29588/857784551.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   dfnew['extract4'] =  dfnew['extract4'].str.replace('\[\[', '')
# C:\Users\Beka\AppData\Local\Temp\5/ipykernel_29588/857784551.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfnew['extract4'] =  dfnew['extract4'].str.replace('\[\[', '')
# C:\Users\Beka\AppData\Local\Temp\5/ipykernel_29588/857784551.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   dfnew['extract4'] =  dfnew['extract4'].str.replace('\]\]', '')
# C:\Users\Beka\AppData\Local\Temp\5/ipykernel_29588/857784551.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfnew['extract4'] =  dfnew['extract4'].str.replace('\]\]', '')
# C:\Users\Beka\AppData\Local\Temp\5/ipykernel_29588/857784551.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   dfnew['extract4'] =  dfnew['extract4'].str.replace('\}\}', '')
# C:\Users\Beka\AppData\Local\Temp\5/ipykernel_29588/857784551.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfnew['extract4'] =  dfnew['extract4'].str.replace('\}\}', '')

# %%
#Deleting white spaces
dfnew['extract4'] =  dfnew['extract4'].str.strip()
# Out:
# C:\Users\Beka\AppData\Local\Temp\5/ipykernel_29588/1894694523.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfnew['extract4'] =  dfnew['extract4'].str.strip()

# %%
dfnew
# Out:
#                                                     Authors  \
# 3777      [{last=Alley, first=Richard B.}, {last=JC Stra...
# 3778      [{link=Joel Mokyr, last=Mokyr, first=Joel\n}, ...
# 3779      [{link=Joel Mokyr, last=Mokyr, first=Joel\n}, ...
# 3780                                                   None
# 3781                             [{last=Falany, first=CN.}]
# ...                                                     ...
# 29181996  [{last=annell, first=LJ}, {last=Taunton, first...
# 29181998      [{link=Peter Suber, last=Suber, first=Peter}]
# 29181999                                               None
# 29182000                [{last=de Souza Ferreira, first=C}]
# 29182001  [{last=Balaji Sitharaman., first=Lalwani, Gaur...
#
#                                                     ID_list  \
# 3777      {ISBN=978-0-8137-2337-2, DOI=10.1130/0-8137-23...
# 3778             {DOI=10.1111/j.1468-0289.1984.tb00344.x\n}
# 3779             {DOI=10.1111/j.1468-0289.1984.tb00344.x\n}
# 3780                                                   None
# 3781        {PMID=9068609, DOI=10.1096/fasebj.11.4.9068609}
# ...                                                     ...
# 29181996  {PMID=11157465, PMC=1724276, DOI=10.1136/bjsm....
# 29181998                       {PMID=21602938, PMC=3090178}
# 29181999                                               None
# 29182000     {PMID=26545644, DOI=10.3305/nh.2015.32.5.9394}
# 29182001  {PMID=25788440, PMC=4552611, DOI=10.1002/jbm.a...
#
#                                                       Title  \
# 3777      Glacial processes, past and present: Glaciaolo...
# 3778      New Developments in Irish Population History, ...
# 3779      New Developments in Irish Population History, ...
# 3780                The True Confessions of Charlotte Doyle
# 3781        Enzymology of human cytosolic sulfotransferases
# ...                                                     ...
# 29181996  A randomised clinical trial of the efficacy of...
# 29181998  An open access mandate for the National Instit...
# 29181999                                     the PWI Awards
# 29182000  Effect of chia seed (Salvia hispanica L.) cons...
# 29182001  Porous three-dimensional carbon nanotube scaff...
#
#                                                   citations        id  \
# 3777      {{Cite journal  | last = Alley  | first =  Ric...  30112151
# 3778      {{Cite journal  | last = Mokyr  | first = Joel...  11693628
# 3779      {{Cite journal  | last = Mokyr  | first = Joel...   1141960
# 3780      {{Cite journal  | last = | first = | title = T...   3057743
# 3781      {{Cite journal  | last1 = Falany | first1 = CN...  29199666
# ...                                                     ...       ...
# 29181996  {{cite journal|year=2001|title=A randomised cl...   1110611
# 29181998  {{cite journal|year=2008|title=An open access ...    296002
# 29181999  {{cite journal|year=2014|journal=[[Pro Wrestli...  14203213
# 29182000  {{cite journal|year=2015|title=Effect of chia ...   2768862
# 29182001  {{cite journal|year=2015|title=Porous three-di...   7452926
#
#                                           page_title  \
# 3777                                   Overdeepening
# 3778                                       Ballitore
# 3779                                        Straffan
# 3780         The True Confessions of Charlotte Doyle
# 3781                   Carbohydrate sulfotransferase
# ...                                              ...
# 29181996                          Muscle contraction
# 29181998                                Darrell Issa
# 29181999                                Seth Rollins
# 29182000                                   Chia seed
# 29182001  Potential applications of carbon nanotubes
#
#                           PublisherName                        extract1  \
# 3777      Geological Society of America             Special Paper 337
# 3778                               None   The Economic History Review
# 3779                               None   The Economic History Review
# 3780                               None    [[The Horn Book Magazine]]
# 3781                               None                        FASEB J
# ...                                 ...                             ...
# 29181996                           None                             NaN
# 29181998                           None                             NaN
# 29181999                           None                             NaN
# 29182000                           None                             NaN
# 29182001                           None                             NaN
#
#                                                  extract2  \
# 3777                                                  NaN
# 3778                                                  NaN
# 3779                                                  NaN
# 3780                                                  NaN
# 3781                                                  NaN
# ...                                                   ...
# 29181996                                  Br J Sports Med
# 29181998                 [[Open Medicine (John Willinsky)
# 29181999                    [[Pro Wrestling Illustrated]]
# 29182000                                        Nutr Hosp
# 29182001  Journal of Biomedical Materials Research Part A
#
#                                                  extract3  \
# 3777                                  Special Paper 337
# 3778                        The Economic History Review
# 3779                        The Economic History Review
# 3780                         [[The Horn Book Magazine]]
# 3781                                             FASEB J
# ...                                                   ...
# 29181996                                  Br J Sports Med
# 29181998                 [[Open Medicine (John Willinsky)
# 29181999                    [[Pro Wrestling Illustrated]]
# 29182000                                        Nutr Hosp
# 29182001  Journal of Biomedical Materials Research Part A
#
#                                                  extract4
# 3777                                    Special Paper 337
# 3778                          The Economic History Review
# 3779                          The Economic History Review
# 3780                               The Horn Book Magazine
# 3781                                              FASEB J
# ...                                                   ...
# 29181996                                  Br J Sports Med
# 29181998                   Open Medicine (John Willinsky)
# 29181999                        Pro Wrestling Illustrated
# 29182000                                        Nutr Hosp
# 29182001  Journal of Biomedical Materials Research Part A
#
# [2014698 rows x 11 columns]

# %%
 dfnew['extract4'].isna().sum()
# Out:
# 0

# %%
df_br.to_excel(r'df_br.xlsx')

# %%
dfnew.to_csv(r'dfnew.csv')

# %%
#Filtering rows with opening brackets
df_br = dfnew[dfnew['extract4'].str.contains('\(')]

# %%
df_final = dfnew.drop(['extract1', 'extract2', 'extract3'], axis = 1)
df_final = df_final.rename(columns = {'extract4':'journal_name'})
df_final
# Out:
#                                                     Authors  \
# 3777      [{last=Alley, first=Richard B.}, {last=JC Stra...
# 3778      [{link=Joel Mokyr, last=Mokyr, first=Joel\n}, ...
# 3779      [{link=Joel Mokyr, last=Mokyr, first=Joel\n}, ...
# 3780                                                   None
# 3781                             [{last=Falany, first=CN.}]
# ...                                                     ...
# 29181996  [{last=annell, first=LJ}, {last=Taunton, first...
# 29181998      [{link=Peter Suber, last=Suber, first=Peter}]
# 29181999                                               None
# 29182000                [{last=de Souza Ferreira, first=C}]
# 29182001  [{last=Balaji Sitharaman., first=Lalwani, Gaur...
#
#                                                     ID_list  \
# 3777      {ISBN=978-0-8137-2337-2, DOI=10.1130/0-8137-23...
# 3778             {DOI=10.1111/j.1468-0289.1984.tb00344.x\n}
# 3779             {DOI=10.1111/j.1468-0289.1984.tb00344.x\n}
# 3780                                                   None
# 3781        {PMID=9068609, DOI=10.1096/fasebj.11.4.9068609}
# ...                                                     ...
# 29181996  {PMID=11157465, PMC=1724276, DOI=10.1136/bjsm....
# 29181998                       {PMID=21602938, PMC=3090178}
# 29181999                                               None
# 29182000     {PMID=26545644, DOI=10.3305/nh.2015.32.5.9394}
# 29182001  {PMID=25788440, PMC=4552611, DOI=10.1002/jbm.a...
#
#                                                       Title  \
# 3777      Glacial processes, past and present: Glaciaolo...
# 3778      New Developments in Irish Population History, ...
# 3779      New Developments in Irish Population History, ...
# 3780                The True Confessions of Charlotte Doyle
# 3781        Enzymology of human cytosolic sulfotransferases
# ...                                                     ...
# 29181996  A randomised clinical trial of the efficacy of...
# 29181998  An open access mandate for the National Instit...
# 29181999                                     the PWI Awards
# 29182000  Effect of chia seed (Salvia hispanica L.) cons...
# 29182001  Porous three-dimensional carbon nanotube scaff...
#
#                                                   citations        id  \
# 3777      {{Cite journal  | last = Alley  | first =  Ric...  30112151
# 3778      {{Cite journal  | last = Mokyr  | first = Joel...  11693628
# 3779      {{Cite journal  | last = Mokyr  | first = Joel...   1141960
# 3780      {{Cite journal  | last = | first = | title = T...   3057743
# 3781      {{Cite journal  | last1 = Falany | first1 = CN...  29199666
# ...                                                     ...       ...
# 29181996  {{cite journal|year=2001|title=A randomised cl...   1110611
# 29181998  {{cite journal|year=2008|title=An open access ...    296002
# 29181999  {{cite journal|year=2014|journal=[[Pro Wrestli...  14203213
# 29182000  {{cite journal|year=2015|title=Effect of chia ...   2768862
# 29182001  {{cite journal|year=2015|title=Porous three-di...   7452926
#
#                                           page_title  \
# 3777                                   Overdeepening
# 3778                                       Ballitore
# 3779                                        Straffan
# 3780         The True Confessions of Charlotte Doyle
# 3781                   Carbohydrate sulfotransferase
# ...                                              ...
# 29181996                          Muscle contraction
# 29181998                                Darrell Issa
# 29181999                                Seth Rollins
# 29182000                                   Chia seed
# 29182001  Potential applications of carbon nanotubes
#
#                           PublisherName  \
# 3777      Geological Society of America
# 3778                               None
# 3779                               None
# 3780                               None
# 3781                               None
# ...                                 ...
# 29181996                           None
# 29181998                           None
# 29181999                           None
# 29182000                           None
# 29182001                           None
#
#                                              journal_name
# 3777                                    Special Paper 337
# 3778                          The Economic History Review
# 3779                          The Economic History Review
# 3780                               The Horn Book Magazine
# 3781                                              FASEB J
# ...                                                   ...
# 29181996                                  Br J Sports Med
# 29181998                   Open Medicine (John Willinsky)
# 29181999                        Pro Wrestling Illustrated
# 29182000                                        Nutr Hosp
# 29182001  Journal of Biomedical Materials Research Part A
#
# [2014698 rows x 8 columns]

# %%
df_final.to_csv(r'df_final.csv')

# %%
df_final.columns
# Out:
# Index(['Authors', 'ID_list', 'Title', 'citations', 'id', 'page_title',
#        'PublisherName', 'journal_name'],
#       dtype='object')

# %%
df_journal = df_final[['page_title', 'journal_name']]

# %%
df_journal
# Out:
#                                           page_title  \
# 3777                                   Overdeepening
# 3778                                       Ballitore
# 3779                                        Straffan
# 3780         The True Confessions of Charlotte Doyle
# 3781                   Carbohydrate sulfotransferase
# ...                                              ...
# 29181996                          Muscle contraction
# 29181998                                Darrell Issa
# 29181999                                Seth Rollins
# 29182000                                   Chia seed
# 29182001  Potential applications of carbon nanotubes
#
#                                              journal_name
# 3777                                    Special Paper 337
# 3778                          The Economic History Review
# 3779                          The Economic History Review
# 3780                               The Horn Book Magazine
# 3781                                              FASEB J
# ...                                                   ...
# 29181996                                  Br J Sports Med
# 29181998                   Open Medicine (John Willinsky)
# 29181999                        Pro Wrestling Illustrated
# 29182000                                        Nutr Hosp
# 29182001  Journal of Biomedical Materials Research Part A
#
# [2014698 rows x 2 columns]

# %%
df_journal.to_csv(r'df_journal.csv', index = False)

# %%
df_journal.head(1000000).to_excel(r'df_journal.xlsx', index = False)

# %%
df_journal
# Out:
#                                           page_title  \
# 3777                                   Overdeepening
# 3778                                       Ballitore
# 3779                                        Straffan
# 3780         The True Confessions of Charlotte Doyle
# 3781                   Carbohydrate sulfotransferase
# ...                                              ...
# 29181996                          Muscle contraction
# 29181998                                Darrell Issa
# 29181999                                Seth Rollins
# 29182000                                   Chia seed
# 29182001  Potential applications of carbon nanotubes
#
#                                              journal_name
# 3777                                    Special Paper 337
# 3778                          The Economic History Review
# 3779                          The Economic History Review
# 3780                               The Horn Book Magazine
# 3781                                              FASEB J
# ...                                                   ...
# 29181996                                  Br J Sports Med
# 29181998                   Open Medicine (John Willinsky)
# 29181999                        Pro Wrestling Illustrated
# 29182000                                        Nutr Hosp
# 29182001  Journal of Biomedical Materials Research Part A
#
# [2014698 rows x 2 columns]

# %%
df_journal = df_journal.drop_duplicates()

# %%
df_journal
# Out:
#                                        page_title  \
# 3777                                Overdeepening
# 3778                                    Ballitore
# 3779                                     Straffan
# 3780      The True Confessions of Charlotte Doyle
# 3781                Carbohydrate sulfotransferase
# ...                                           ...
# 29181994          The Origins of the Urban Crisis
# 29181995                                   Laelia
# 29181996                       Muscle contraction
# 29181998                             Darrell Issa
# 29182000                                Chia seed
#
#                                 journal_name
# 3777                       Special Paper 337
# 3778             The Economic History Review
# 3779             The Economic History Review
# 3780                  The Horn Book Magazine
# 3781                                 FASEB J
# ...                                      ...
# 29181994  The Journal for MultiMedia History
# 29181995                          Lindleyana
# 29181996                     Br J Sports Med
# 29181998      Open Medicine (John Willinsky)
# 29182000                           Nutr Hosp
#
# [1569780 rows x 2 columns]

# %%
df_journal.to_csv(r'df_journal.csv',  index = False)

# %%
read = pd.read_csv('df_journal.csv')
read
# Out:
#          Unnamed: 0                               page_title  \
# 0              3777                            Overdeepening
# 1              3778                                Ballitore
# 2              3779                                 Straffan
# 3              3780  The True Confessions of Charlotte Doyle
# 4              3781            Carbohydrate sulfotransferase
# ...             ...                                      ...
# 1569775    29181994          The Origins of the Urban Crisis
# 1569776    29181995                                   Laelia
# 1569777    29181996                       Muscle contraction
# 1569778    29181998                             Darrell Issa
# 1569779    29182000                                Chia seed
#
#                                journal_name
# 0                         Special Paper 337
# 1               The Economic History Review
# 2               The Economic History Review
# 3                    The Horn Book Magazine
# 4                                   FASEB J
# ...                                     ...
# 1569775  The Journal for MultiMedia History
# 1569776                          Lindleyana
# 1569777                     Br J Sports Med
# 1569778      Open Medicine (John Willinsky)
# 1569779                           Nutr Hosp
#
# [1569780 rows x 3 columns]

# %%
# df_journal = df_journal.replace(r'[^\w\s\~]_', '', regex=True)
df_journal = df_final[['page_title', 'journal_name']]


df_journal = df_journal.sort_values(by=['journal_name'], ascending=False)
df_journal
# Out:
#                                           page_title journal_name
# 27568282                             Aceria clianthi        ~Weta
# 24637003                        Third-person pronoun          {{w
# 1511789                                  Eoentelodon     {{transl
# 27129331                             Madanjeet Singh    {{subst:^
# 24341983  List of television stations in Mississippi        {{req
# ...                                              ...          ...
# 15224075                             Virtual fixture
# 13614697                         Education in Brazil
# 13614696                                       Qormi
# 5902525                                     Hitta J3
# 20537377                       Cambodian jungle girl
#
# [2014698 rows x 2 columns]

# %%
df_journal = df_journal.replace(r'[^\w\s]+', '', regex=True)
df_journal
# Out:
#                                           page_title journal_name
# 27568282                             Aceria clianthi         Weta
# 24637003                         Thirdperson pronoun            w
# 1511789                                  Eoentelodon       transl
# 27129331                             Madanjeet Singh        subst
# 24341983  List of television stations in Mississippi          req
# ...                                              ...          ...
# 15224075                             Virtual fixture
# 13614697                         Education in Brazil
# 13614696                                       Qormi
# 5902525                                     Hitta J3
# 20537377                       Cambodian jungle girl
#
# [2014698 rows x 2 columns]
